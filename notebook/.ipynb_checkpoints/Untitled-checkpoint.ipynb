# %%
from polars import DataFrame, col

# %%
TX = DatFrame(
    timestamp: [],
    qty: [], # +buy, -sell
    price: []
)

Q = DataFRame(
    timestamp: [],
    price: []
)
# Out:
#   Cell In[13], line 2
#     timestamp: [],
#              ^
# SyntaxError: invalid syntax
